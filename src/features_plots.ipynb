# %% [markdown]
# # Settings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import features as ft
import re

# %% [markdown]
# # Data

# %%
# Path to the directory containing the data files
source_path = "D:/Popocatepetl/processed_data/2023"
paths = os.listdir(source_path)

# %%
# Filter files for a specific month
month = 'CN_PPPP_HHZ_2023_05'
with_s = [x for x in paths if re.match(r'^{}'.format(month), x)]
with_s.sort()
print(with_s)
# Out:
# ['CN_PPPP_HHZ_2023_05_01.seed', 'CN_PPPP_HHZ_2023_05_02.seed', 'CN_PPPP_HHZ_2023_05_03.seed', 'CN_PPPP_HHZ_2023_05_04.seed', 'CN_PPPP_HHZ_2023_05_05.seed', 'CN_PPPP_HHZ_2023_05_06.seed', 'CN_PPPP_HHZ_2023_05_07.seed', 'CN_PPPP_HHZ_2023_05_08.seed', 'CN_PPPP_HHZ_2023_05_09.seed', 'CN_PPPP_HHZ_2023_05_10.seed', 'CN_PPPP_HHZ_2023_05_11.seed', 'CN_PPPP_HHZ_2023_05_12.seed', 'CN_PPPP_HHZ_2023_05_13.seed', 'CN_PPPP_HHZ_2023_05_14.seed', 'CN_PPPP_HHZ_2023_05_15.seed', 'CN_PPPP_HHZ_2023_05_16.seed', 'CN_PPPP_HHZ_2023_05_17.seed', 'CN_PPPP_HHZ_2023_05_18.seed', 'CN_PPPP_HHZ_2023_05_19.seed', 'CN_PPPP_HHZ_2023_05_20.seed', 'CN_PPPP_HHZ_2023_05_21.seed', 'CN_PPPP_HHZ_2023_05_22.seed', 'CN_PPPP_HHZ_2023_05_23.seed', 'CN_PPPP_HHZ_2023_05_24.seed', 'CN_PPPP_HHZ_2023_05_25.seed', 'CN_PPPP_HHZ_2023_05_26.seed', 'CN_PPPP_HHZ_2023_05_27.seed', 'CN_PPPP_HHZ_2023_05_28.seed', 'CN_PPPP_HHZ_2023_05_29.seed', 'CN_PPPP_HHZ_2023_05_30.seed', 'CN_PPPP_HHZ_2023_05_31.seed']

# %% [markdown]
# # Calculate features

# %%
# Test the features in the range of 0.7 to 30 Hz
min_freq = 0.7
max_freq = 30
# DataFrame to store all features
features_df = pd.DataFrame(columns=["timestamp", "energy", "kurtosis", "frecuency_index", "entropy"])
# Loop through each file and extract features
for file in with_s:
    print(file)
    [filtered_signal, s_low, s_high] = ft.load_and_preprocess_seismic_data(source_path+"/"+file, freqmin=min_freq, freqmax=max_freq, low_freqmin=1, low_freqmax=4, high_freqmin=4, high_freqmax=9)
    day_df = ft.calculate_features(filtered_signal[0], s_low[0], s_high[0], window_size_seconds=600, overlap=0.5)
    features_df = pd.concat([features_df, day_df], ignore_index=True)
# Out:
# CN_PPPP_HHZ_2023_05_01.seed
# C:\Users\javie\AppData\Local\Temp\ipykernel_24900\2572249672.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   features_df = pd.concat([features_df, day_df], ignore_index=True)
# CN_PPPP_HHZ_2023_05_02.seed
# CN_PPPP_HHZ_2023_05_03.seed
# CN_PPPP_HHZ_2023_05_04.seed
# CN_PPPP_HHZ_2023_05_05.seed
# CN_PPPP_HHZ_2023_05_06.seed
# CN_PPPP_HHZ_2023_05_07.seed
# CN_PPPP_HHZ_2023_05_08.seed
# CN_PPPP_HHZ_2023_05_09.seed
# CN_PPPP_HHZ_2023_05_10.seed
# CN_PPPP_HHZ_2023_05_11.seed
# CN_PPPP_HHZ_2023_05_12.seed
# CN_PPPP_HHZ_2023_05_13.seed
# CN_PPPP_HHZ_2023_05_14.seed
# CN_PPPP_HHZ_2023_05_15.seed
# CN_PPPP_HHZ_2023_05_16.seed
# CN_PPPP_HHZ_2023_05_17.seed
# CN_PPPP_HHZ_2023_05_18.seed
# CN_PPPP_HHZ_2023_05_19.seed
# CN_PPPP_HHZ_2023_05_20.seed
# CN_PPPP_HHZ_2023_05_21.seed
# CN_PPPP_HHZ_2023_05_22.seed
# CN_PPPP_HHZ_2023_05_23.seed
# CN_PPPP_HHZ_2023_05_24.seed
# CN_PPPP_HHZ_2023_05_25.seed
# CN_PPPP_HHZ_2023_05_26.seed
# CN_PPPP_HHZ_2023_05_27.seed
# CN_PPPP_HHZ_2023_05_28.seed
# CN_PPPP_HHZ_2023_05_29.seed
# CN_PPPP_HHZ_2023_05_30.seed
# CN_PPPP_HHZ_2023_05_31.seed

# %% [markdown]
# ## Energy

# %%
hours = 4
# Calculate moving average and median for energy feature
features_df['energy_movil_media'] = features_df['energy'].rolling(window=11*hours, center=True).mean()
#features_df['energy_movil_mediana'] = features_df['energy'].rolling(window=12, center=True).median()

# %%
fig1, ax1 = plt.subplots(figsize=(11, 6))
# Energy
ax1.scatter(features_df['timestamp'], features_df['energy'], color='paleturquoise', s=10, alpha=0.6, label="Ventana de 10 min")
# Moving average
ax1.plot(features_df['timestamp'], features_df['energy_movil_media'], color='teal', linewidth=2, label=f'Media móvil centrada ({hours} hr)')
ax1.set_yscale('log')
ax1.set_title('Energía (Cuadrados medios de la amplitud)')
ax1.set_xlabel('Fecha')
ax1.legend(loc='best')
plt.xticks(rotation=45)
plt.tight_layout()
#fig1.savefig(r"C:\Users\javie\OneDrive - INSTITUTO TECNOLOGICO AUTONOMO DE MEXICO\MaestriaEnCienciaDeDatos\EstanciaDeInvestigacion\Popocatepelt\PopocatepetlVolcano\img\ReporteEstancia\Energy_may.pdf", bbox_inches="tight", dpi=300)
#plt.close(fig1)

# %% [markdown]
# ## Kurtosis

# %%
# Calculate moving average for kurtosis feature
features_df['kurtosis_movil_media'] = features_df['kurtosis'].rolling(window=11*hours, center=True).mean()

# %%
# Calculate moving variance for kurtosis feature
features_df['kurtosis_mobile_variance'] = features_df['kurtosis'].rolling(window=11*hours, center=True).var()

# %%
fig2, ax21 = plt.subplots(figsize=(11, 6))
ax22 = ax21.twinx()

# Kurtosis
ax21.scatter(features_df['timestamp'], features_df['kurtosis'], color='lightsteelblue', s=10, alpha=0.5, label="Ventana de 10 min")
ax21.set_ylabel('Kurtosis', color='black')
ax21.tick_params(axis='y', labelcolor='black')

# Moving variance
ax22.plot(features_df['timestamp'], features_df['kurtosis_mobile_variance'], color='navy', alpha=1, linewidth=2, label=f'Varianza móvil centrada ({hours} hr)')
ax22.set_ylabel('Varianza móvil', color='navy')
ax22.tick_params(axis='y', labelcolor='navy')

ax21.set_title('Kurtosis')
ax21.set_xlabel('Fecha')
plt.xticks(rotation=45)
plt.tight_layout()
# fig2.savefig(r"C:/Users/LENOVO/OneDrive/Documentos/Estancia de Investigación/PopocatepetlVolcano/img/Kurtosis_may_media.pdf", bbox_inches="tight", dpi=300)
# plt.close(fig2)

# %% [markdown]
# ## Frequency Index

# %%
# Calculate moving average for frequency index feature
features_df['frequency_index_movil_media'] = features_df['frequency_index'].rolling(window=11*hours, center=True).mean()

# %%
fig3, ax3 = plt.subplots(figsize=(11, 6))
# Frequency Index
ax3.scatter(features_df['timestamp'], features_df['frequency_index'], color='#7FB3D5', s=10, alpha=0.5, label = "Ventana de 10 min")
# Moving average
ax3.plot(features_df['timestamp'], features_df['frequency_index_movil_media'], color='#C0392B', alpha = 1,linewidth=2, label=f'Media móvil centrada ({hours} hr)')
ax3.set_title('Índice de frecuencia')
ax3.set_xlabel('Fecha')
ax3.legend(loc='best')
plt.xticks(rotation=45)
plt.tight_layout()
# fig3.savefig(r"C:/Users/LENOVO/OneDrive/Documentos/Estancia de Investigación/PopocatepetlVolcano/img/Frequency_index_may_media.pdf", bbox_inches="tight", dpi=300)
# plt.close(fig3)

# %% [markdown]
# ## Entropy

# %%
# Calculate moving average for entropy feature
features_df['entropy_movil_media'] = features_df['entropy'].rolling(window=11*hours, center=True).mean()

# %%
fig4, ax4 = plt.subplots(figsize=(11, 6))
# Entropy
ax4.scatter(features_df['timestamp'], features_df['entropy'], color='silver', s=10, alpha=0.5, label = "Ventana de 10 min")
# Moving average
ax4.plot(features_df['timestamp'], features_df['entropy_movil_media'], color='darkorange', alpha = 1,linewidth=2, label=f'Media móvil centrada ({hours} hr)')
ax4.set_title('Entropia')
ax4.set_xlabel('Fecha')
ax4.legend(loc='best')
plt.xticks(rotation=45)
plt.tight_layout()
# fig4.savefig(r"C:/Users/LENOVO/OneDrive/Documentos/Estancia de Investigación/PopocatepetlVolcano/img/Entropy_may_media.pdf", bbox_inches="tight", dpi=300)
# plt.close(fig4)

# %% [markdown]
# ## Joint plot features for 2022

# %%
# Path to the directory containing the data files
source_path = "D:/Popocatepetl/processed_data/2022"
paths = os.listdir(source_path)

# Filter files for a specific month
month = ''
with_s = [x for x in paths if re.match(r'^{}'.format(month), x)]
with_s.sort()
print(with_s)

# Test the features in the range of 0.7 to 30 Hz
min_freq = 0.7
max_freq = 30
# DataFrame to store all features
features_df = pd.DataFrame(columns=["timestamp", "energy", "kurtosis", "frecuency_index", "entropy"])
# Loop through each file and extract features
for file in with_s:
    print(file)
    [filtered_signal, s_low, s_high] = ft.load_and_preprocess_seismic_data(source_path+"/"+file, freqmin=min_freq, freqmax=max_freq, low_freqmin=1, low_freqmax=4, high_freqmin=4, high_freqmax=9)
    day_df = ft.calculate_features(filtered_signal[0], s_low[0], s_high[0], window_size_seconds=600, overlap=0.5)
    features_df = pd.concat([features_df, day_df], ignore_index=True)

# Calculate moving average for all features
features_df['energy_movil_media'] = features_df['energy'].rolling(window=12, center=True).mean()
features_df['kurtosis_movil_media'] = features_df['kurtosis'].rolling(window=12, center=True).mean()
features_df['frequency_index_movil_media'] = features_df['frequency_index'].rolling(window=12, center=True).mean()
features_df['entropy_movil_media'] = features_df['entropy'].rolling(window=12, center=True).mean()
# Out:
# ['CN_PPPP_HHZ_2022_01_01.seed', 'CN_PPPP_HHZ_2022_01_02.seed', 'CN_PPPP_HHZ_2022_01_03.seed', 'CN_PPPP_HHZ_2022_01_04.seed', 'CN_PPPP_HHZ_2022_01_05.seed', 'CN_PPPP_HHZ_2022_01_06.seed', 'CN_PPPP_HHZ_2022_01_07.seed', 'CN_PPPP_HHZ_2022_01_08.seed', 'CN_PPPP_HHZ_2022_01_09.seed', 'CN_PPPP_HHZ_2022_01_10.seed', 'CN_PPPP_HHZ_2022_01_11.seed', 'CN_PPPP_HHZ_2022_01_12.seed', 'CN_PPPP_HHZ_2022_01_13.seed', 'CN_PPPP_HHZ_2022_01_14.seed', 'CN_PPPP_HHZ_2022_01_15.seed', 'CN_PPPP_HHZ_2022_01_16.seed', 'CN_PPPP_HHZ_2022_01_17.seed', 'CN_PPPP_HHZ_2022_01_18.seed', 'CN_PPPP_HHZ_2022_01_19.seed', 'CN_PPPP_HHZ_2022_01_20.seed', 'CN_PPPP_HHZ_2022_01_21.seed', 'CN_PPPP_HHZ_2022_01_22.seed', 'CN_PPPP_HHZ_2022_01_23.seed', 'CN_PPPP_HHZ_2022_01_24.seed', 'CN_PPPP_HHZ_2022_01_25.seed', 'CN_PPPP_HHZ_2022_01_26.seed', 'CN_PPPP_HHZ_2022_01_27.seed', 'CN_PPPP_HHZ_2022_01_28.seed', 'CN_PPPP_HHZ_2022_01_29.seed', 'CN_PPPP_HHZ_2022_01_30.seed', 'CN_PPPP_HHZ_2022_01_31.seed', 'CN_PPPP_HHZ_2022_02_01.seed', 'CN_PPPP_HHZ_2022_02_02.seed', 'CN_PPPP_HHZ_2022_02_03.seed', 'CN_PPPP_HHZ_2022_02_04.seed', 'CN_PPPP_HHZ_2022_02_05.seed', 'CN_PPPP_HHZ_2022_02_06.seed', 'CN_PPPP_HHZ_2022_02_07.seed', 'CN_PPPP_HHZ_2022_02_08.seed', 'CN_PPPP_HHZ_2022_02_09.seed', 'CN_PPPP_HHZ_2022_02_10.seed', 'CN_PPPP_HHZ_2022_02_11.seed', 'CN_PPPP_HHZ_2022_02_12.seed', 'CN_PPPP_HHZ_2022_02_13.seed', 'CN_PPPP_HHZ_2022_02_14.seed', 'CN_PPPP_HHZ_2022_02_15.seed', 'CN_PPPP_HHZ_2022_02_16.seed', 'CN_PPPP_HHZ_2022_02_17.seed', 'CN_PPPP_HHZ_2022_02_18.seed', 'CN_PPPP_HHZ_2022_02_19.seed', 'CN_PPPP_HHZ_2022_02_20.seed', 'CN_PPPP_HHZ_2022_02_21.seed', 'CN_PPPP_HHZ_2022_02_22.seed', 'CN_PPPP_HHZ_2022_02_23.seed', 'CN_PPPP_HHZ_2022_02_24.seed', 'CN_PPPP_HHZ_2022_02_25.seed', 'CN_PPPP_HHZ_2022_02_26.seed', 'CN_PPPP_HHZ_2022_02_27.seed', 'CN_PPPP_HHZ_2022_02_28.seed', 'CN_PPPP_HHZ_2022_03_01.seed', 'CN_PPPP_HHZ_2022_03_02.seed', 'CN_PPPP_HHZ_2022_03_03.seed', 'CN_PPPP_HHZ_2022_03_04.seed', 'CN_PPPP_HHZ_2022_03_05.seed', 'CN_PPPP_HHZ_2022_03_06.seed', 'CN_PPPP_HHZ_2022_03_07.seed', 'CN_PPPP_HHZ_2022_03_08.seed', 'CN_PPPP_HHZ_2022_03_09.seed', 'CN_PPPP_HHZ_2022_03_10.seed', 'CN_PPPP_HHZ_2022_03_11.seed', 'CN_PPPP_HHZ_2022_03_12.seed', 'CN_PPPP_HHZ_2022_03_13.seed', 'CN_PPPP_HHZ_2022_03_14.seed', 'CN_PPPP_HHZ_2022_03_15.seed', 'CN_PPPP_HHZ_2022_03_16.seed', 'CN_PPPP_HHZ_2022_03_17.seed', 'CN_PPPP_HHZ_2022_03_18.seed', 'CN_PPPP_HHZ_2022_03_19.seed', 'CN_PPPP_HHZ_2022_03_20.seed', 'CN_PPPP_HHZ_2022_03_21.seed', 'CN_PPPP_HHZ_2022_03_22.seed', 'CN_PPPP_HHZ_2022_03_23.seed', 'CN_PPPP_HHZ_2022_03_24.seed', 'CN_PPPP_HHZ_2022_03_25.seed', 'CN_PPPP_HHZ_2022_03_26.seed', 'CN_PPPP_HHZ_2022_03_27.seed', 'CN_PPPP_HHZ_2022_03_28.seed', 'CN_PPPP_HHZ_2022_03_29.seed', 'CN_PPPP_HHZ_2022_03_30.seed', 'CN_PPPP_HHZ_2022_03_31.seed', 'CN_PPPP_HHZ_2022_04_01.seed', 'CN_PPPP_HHZ_2022_04_02.seed', 'CN_PPPP_HHZ_2022_04_03.seed', 'CN_PPPP_HHZ_2022_04_04.seed', 'CN_PPPP_HHZ_2022_04_05.seed', 'CN_PPPP_HHZ_2022_04_06.seed', 'CN_PPPP_HHZ_2022_04_07.seed', 'CN_PPPP_HHZ_2022_04_08.seed', 'CN_PPPP_HHZ_2022_04_09.seed', 'CN_PPPP_HHZ_2022_04_10.seed', 'CN_PPPP_HHZ_2022_04_11.seed', 'CN_PPPP_HHZ_2022_04_12.seed', 'CN_PPPP_HHZ_2022_04_13.seed', 'CN_PPPP_HHZ_2022_04_14.seed', 'CN_PPPP_HHZ_2022_04_15.seed', 'CN_PPPP_HHZ_2022_04_16.seed', 'CN_PPPP_HHZ_2022_04_17.seed', 'CN_PPPP_HHZ_2022_04_18.seed', 'CN_PPPP_HHZ_2022_04_19.seed', 'CN_PPPP_HHZ_2022_04_20.seed', 'CN_PPPP_HHZ_2022_04_21.seed', 'CN_PPPP_HHZ_2022_04_22.seed', 'CN_PPPP_HHZ_2022_04_23.seed', 'CN_PPPP_HHZ_2022_04_24.seed', 'CN_PPPP_HHZ_2022_04_25.seed', 'CN_PPPP_HHZ_2022_04_26.seed', 'CN_PPPP_HHZ_2022_04_27.seed', 'CN_PPPP_HHZ_2022_04_28.seed', 'CN_PPPP_HHZ_2022_04_29.seed', 'CN_PPPP_HHZ_2022_04_30.seed', 'CN_PPPP_HHZ_2022_05_01.seed', 'CN_PPPP_HHZ_2022_05_02.seed', 'CN_PPPP_HHZ_2022_05_03.seed', 'CN_PPPP_HHZ_2022_05_04.seed', 'CN_PPPP_HHZ_2022_05_05.seed', 'CN_PPPP_HHZ_2022_05_06.seed', 'CN_PPPP_HHZ_2022_05_07.seed', 'CN_PPPP_HHZ_2022_05_08.seed', 'CN_PPPP_HHZ_2022_05_09.seed',  ...
# CN_PPPP_HHZ_2022_01_01.seed
# C:\Users\javie\AppData\Local\Temp\ipykernel_24900\2044347297.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   features_df = pd.concat([features_df, day_df], ignore_index=True)
# CN_PPPP_HHZ_2022_01_02.seed
# CN_PPPP_HHZ_2022_01_03.seed
# CN_PPPP_HHZ_2022_01_04.seed
# CN_PPPP_HHZ_2022_01_05.seed
# CN_PPPP_HHZ_2022_01_06.seed
# CN_PPPP_HHZ_2022_01_07.seed
# CN_PPPP_HHZ_2022_01_08.seed
# CN_PPPP_HHZ_2022_01_09.seed
# CN_PPPP_HHZ_2022_01_10.seed
# CN_PPPP_HHZ_2022_01_11.seed
# CN_PPPP_HHZ_2022_01_12.seed
# CN_PPPP_HHZ_2022_01_13.seed
# CN_PPPP_HHZ_2022_01_14.seed
# CN_PPPP_HHZ_2022_01_15.seed
# CN_PPPP_HHZ_2022_01_16.seed
# CN_PPPP_HHZ_2022_01_17.seed
# CN_PPPP_HHZ_2022_01_18.seed
# CN_PPPP_HHZ_2022_01_19.seed
# CN_PPPP_HHZ_2022_01_20.seed
# CN_PPPP_HHZ_2022_01_21.seed
# CN_PPPP_HHZ_2022_01_22.seed
# CN_PPPP_HHZ_2022_01_23.seed
# CN_PPPP_HHZ_2022_01_24.seed
# CN_PPPP_HHZ_2022_01_25.seed
# CN_PPPP_HHZ_2022_01_26.seed
# CN_PPPP_HHZ_2022_01_27.seed
# CN_PPPP_HHZ_2022_01_28.seed
# CN_PPPP_HHZ_2022_01_29.seed
# CN_PPPP_HHZ_2022_01_30.seed
# CN_PPPP_HHZ_2022_01_31.seed
# CN_PPPP_HHZ_2022_02_01.seed
# CN_PPPP_HHZ_2022_02_02.seed
# CN_PPPP_HHZ_2022_02_03.seed
# CN_PPPP_HHZ_2022_02_04.seed
# CN_PPPP_HHZ_2022_02_05.seed
# CN_PPPP_HHZ_2022_02_06.seed
# CN_PPPP_HHZ_2022_02_07.seed
# CN_PPPP_HHZ_2022_02_08.seed
# CN_PPPP_HHZ_2022_02_09.seed
# CN_PPPP_HHZ_2022_02_10.seed
# CN_PPPP_HHZ_2022_02_11.seed
# CN_PPPP_HHZ_2022_02_12.seed
# CN_PPPP_HHZ_2022_02_13.seed
# CN_PPPP_HHZ_2022_02_14.seed
# CN_PPPP_HHZ_2022_02_15.seed
# CN_PPPP_HHZ_2022_02_16.seed
# CN_PPPP_HHZ_2022_02_17.seed
# CN_PPPP_HHZ_2022_02_18.seed
# CN_PPPP_HHZ_2022_02_19.seed
# CN_PPPP_HHZ_2022_02_20.seed
# CN_PPPP_HHZ_2022_02_21.seed
# CN_PPPP_HHZ_2022_02_22.seed
# CN_PPPP_HHZ_2022_02_23.seed
# CN_PPPP_HHZ_2022_02_24.seed
# CN_PPPP_HHZ_2022_02_25.seed
# CN_PPPP_HHZ_2022_02_26.seed
# CN_PPPP_HHZ_2022_02_27.seed
# CN_PPPP_HHZ_2022_02_28.seed
# CN_PPPP_HHZ_2022_03_01.seed
# CN_PPPP_HHZ_2022_03_02.seed
# CN_PPPP_HHZ_2022_03_03.seed
# CN_PPPP_HHZ_2022_03_04.seed
# CN_PPPP_HHZ_2022_03_05.seed
# CN_PPPP_HHZ_2022_03_06.seed
# CN_PPPP_HHZ_2022_03_07.seed
# CN_PPPP_HHZ_2022_03_08.seed
# CN_PPPP_HHZ_2022_03_09.seed
# CN_PPPP_HHZ_2022_03_10.seed
# CN_PPPP_HHZ_2022_03_11.seed
# CN_PPPP_HHZ_2022_03_12.seed
# CN_PPPP_HHZ_2022_03_13.seed
# CN_PPPP_HHZ_2022_03_14.seed
# CN_PPPP_HHZ_2022_03_15.seed
# CN_PPPP_HHZ_2022_03_16.seed
# CN_PPPP_HHZ_2022_03_17.seed
# CN_PPPP_HHZ_2022_03_18.seed
# CN_PPPP_HHZ_2022_03_19.seed
# CN_PPPP_HHZ_2022_03_20.seed
# CN_PPPP_HHZ_2022_03_21.seed
# CN_PPPP_HHZ_2022_03_22.seed
# CN_PPPP_HHZ_2022_03_23.seed
# CN_PPPP_HHZ_2022_03_24.seed
# CN_PPPP_HHZ_2022_03_25.seed
# CN_PPPP_HHZ_2022_03_26.seed
# CN_PPPP_HHZ_2022_03_27.seed
# CN_PPPP_HHZ_2022_03_28.seed
# CN_PPPP_HHZ_2022_03_29.seed
# CN_PPPP_HHZ_2022_03_30.seed
# CN_PPPP_HHZ_2022_03_31.seed
# CN_PPPP_HHZ_2022_04_01.seed
# CN_PPPP_HHZ_2022_04_02.seed
# CN_PPPP_HHZ_2022_04_03.seed
# CN_PPPP_HHZ_2022_04_04.seed
# CN_PPPP_HHZ_2022_04_05.seed
# CN_PPPP_HHZ_2022_04_06.seed
# CN_PPPP_HHZ_2022_04_07.seed
# CN_PPPP_HHZ_2022_04_08.seed
# CN_PPPP_HHZ_2022_04_09.seed
# CN_PPPP_HHZ_2022_04_10.seed
# CN_PPPP_HHZ_2022_04_11.seed
# CN_PPPP_HHZ_2022_04_12.seed
# CN_PPPP_HHZ_2022_04_13.seed
# CN_PPPP_HHZ_2022_04_14.seed
# CN_PPPP_HHZ_2022_04_15.seed
# CN_PPPP_HHZ_2022_04_16.seed
# CN_PPPP_HHZ_2022_04_17.seed
# CN_PPPP_HHZ_2022_04_18.seed
# CN_PPPP_HHZ_2022_04_19.seed
# CN_PPPP_HHZ_2022_04_20.seed
# CN_PPPP_HHZ_2022_04_21.seed
# CN_PPPP_HHZ_2022_04_22.seed
# c:\Users\javie\OneDrive - INSTITUTO TECNOLOGICO AUTONOMO DE MEXICO\MaestriaEnCienciaDeDatos\EstanciaDeInvestigacion\Popocatepelt\PopocatepetlVolcano\src\features.py:131: RuntimeWarning: divide by zero encountered in log10
#   freq_index = np.log10(ener_high / (ener_low + np.finfo(float).eps))
# c:\Users\javie\miniconda3\envs\estancia_popocatepetl\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2046: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# CN_PPPP_HHZ_2022_04_23.seed
# CN_PPPP_HHZ_2022_04_24.seed
# CN_PPPP_HHZ_2022_04_25.seed
# CN_PPPP_HHZ_2022_04_26.seed
# CN_PPPP_HHZ_2022_04_27.seed
# CN_PPPP_HHZ_2022_04_28.seed
# CN_PPPP_HHZ_2022_04_29.seed
# CN_PPPP_HHZ_2022_04_30.seed
# CN_PPPP_HHZ_2022_05_01.seed
# CN_PPPP_HHZ_2022_05_02.seed
# CN_PPPP_HHZ_2022_05_03.seed
# CN_PPPP_HHZ_2022_05_04.seed
# CN_PPPP_HHZ_2022_05_05.seed
# CN_PPPP_HHZ_2022_05_06.seed
# CN_PPPP_HHZ_2022_05_07.seed
# CN_PPPP_HHZ_2022_05_08.seed
# CN_PPPP_HHZ_2022_05_09.seed
# CN_PPPP_HHZ_2022_05_10.seed
# CN_PPPP_HHZ_2022_05_11.seed
# CN_PPPP_HHZ_2022_05_12.seed
# CN_PPPP_HHZ_2022_05_13.seed
# CN_PPPP_HHZ_2022_05_14.seed
# CN_PPPP_HHZ_2022_05_15.seed
# CN_PPPP_HHZ_2022_05_16.seed
# CN_PPPP_HHZ_2022_05_17.seed
# CN_PPPP_HHZ_2022_05_18.seed
# CN_PPPP_HHZ_2022_05_19.seed
# CN_PPPP_HHZ_2022_05_20.seed
# CN_PPPP_HHZ_2022_05_21.seed
# CN_PPPP_HHZ_2022_05_22.seed
# CN_PPPP_HHZ_2022_05_23.seed
# CN_PPPP_HHZ_2022_05_24.seed
# CN_PPPP_HHZ_2022_05_25.seed
# CN_PPPP_HHZ_2022_05_26.seed
# CN_PPPP_HHZ_2022_05_27.seed
# CN_PPPP_HHZ_2022_05_28.seed
# CN_PPPP_HHZ_2022_05_29.seed
# CN_PPPP_HHZ_2022_05_30.seed
# CN_PPPP_HHZ_2022_05_31.seed
# CN_PPPP_HHZ_2022_06_01.seed
# CN_PPPP_HHZ_2022_06_02.seed
# CN_PPPP_HHZ_2022_06_03.seed
# CN_PPPP_HHZ_2022_06_04.seed
# CN_PPPP_HHZ_2022_06_05.seed
# CN_PPPP_HHZ_2022_06_06.seed
# CN_PPPP_HHZ_2022_06_07.seed
# CN_PPPP_HHZ_2022_06_08.seed
# CN_PPPP_HHZ_2022_06_09.seed
# CN_PPPP_HHZ_2022_06_10.seed
# CN_PPPP_HHZ_2022_06_11.seed
# CN_PPPP_HHZ_2022_06_12.seed
# CN_PPPP_HHZ_2022_06_13.seed
# CN_PPPP_HHZ_2022_06_14.seed
# CN_PPPP_HHZ_2022_06_15.seed
# CN_PPPP_HHZ_2022_06_16.seed
# CN_PPPP_HHZ_2022_06_17.seed
# CN_PPPP_HHZ_2022_06_18.seed
# CN_PPPP_HHZ_2022_06_19.seed
# CN_PPPP_HHZ_2022_06_20.seed
# CN_PPPP_HHZ_2022_06_21.seed
# CN_PPPP_HHZ_2022_06_22.seed
# CN_PPPP_HHZ_2022_06_23.seed
# CN_PPPP_HHZ_2022_06_24.seed
# CN_PPPP_HHZ_2022_06_25.seed
# CN_PPPP_HHZ_2022_06_26.seed
# CN_PPPP_HHZ_2022_06_27.seed
# CN_PPPP_HHZ_2022_06_28.seed
# CN_PPPP_HHZ_2022_06_29.seed
# CN_PPPP_HHZ_2022_06_30.seed
# CN_PPPP_HHZ_2022_07_01.seed
# CN_PPPP_HHZ_2022_07_02.seed
# CN_PPPP_HHZ_2022_07_03.seed
# CN_PPPP_HHZ_2022_07_04.seed
# CN_PPPP_HHZ_2022_07_05.seed
# CN_PPPP_HHZ_2022_07_06.seed
# CN_PPPP_HHZ_2022_07_07.seed
# CN_PPPP_HHZ_2022_07_08.seed
# CN_PPPP_HHZ_2022_07_09.seed
# CN_PPPP_HHZ_2022_07_10.seed
# CN_PPPP_HHZ_2022_07_11.seed
# CN_PPPP_HHZ_2022_07_12.seed
# CN_PPPP_HHZ_2022_07_13.seed
# CN_PPPP_HHZ_2022_07_14.seed
# CN_PPPP_HHZ_2022_07_15.seed
# CN_PPPP_HHZ_2022_07_16.seed
# CN_PPPP_HHZ_2022_07_17.seed
# CN_PPPP_HHZ_2022_07_18.seed
# CN_PPPP_HHZ_2022_07_19.seed
# CN_PPPP_HHZ_2022_07_20.seed
# CN_PPPP_HHZ_2022_07_21.seed
# CN_PPPP_HHZ_2022_07_22.seed
# CN_PPPP_HHZ_2022_07_23.seed
# CN_PPPP_HHZ_2022_07_24.seed
# CN_PPPP_HHZ_2022_07_25.seed
# CN_PPPP_HHZ_2022_07_26.seed
# CN_PPPP_HHZ_2022_07_27.seed
# CN_PPPP_HHZ_2022_07_28.seed
# CN_PPPP_HHZ_2022_07_29.seed
# CN_PPPP_HHZ_2022_07_30.seed
# CN_PPPP_HHZ_2022_07_31.seed
# CN_PPPP_HHZ_2022_08_01.seed
# CN_PPPP_HHZ_2022_08_02.seed
# CN_PPPP_HHZ_2022_08_03.seed
# CN_PPPP_HHZ_2022_08_04.seed
# CN_PPPP_HHZ_2022_08_05.seed
# CN_PPPP_HHZ_2022_08_06.seed
# CN_PPPP_HHZ_2022_08_07.seed
# CN_PPPP_HHZ_2022_08_08.seed
# CN_PPPP_HHZ_2022_08_09.seed
# CN_PPPP_HHZ_2022_08_10.seed
# CN_PPPP_HHZ_2022_08_11.seed
# CN_PPPP_HHZ_2022_08_12.seed
# CN_PPPP_HHZ_2022_08_13.seed
# CN_PPPP_HHZ_2022_08_14.seed
# CN_PPPP_HHZ_2022_08_15.seed
# CN_PPPP_HHZ_2022_08_16.seed
# CN_PPPP_HHZ_2022_08_17.seed
# CN_PPPP_HHZ_2022_08_18.seed
# CN_PPPP_HHZ_2022_08_19.seed
# CN_PPPP_HHZ_2022_08_20.seed
# CN_PPPP_HHZ_2022_08_21.seed
# CN_PPPP_HHZ_2022_08_22.seed
# CN_PPPP_HHZ_2022_08_23.seed
# CN_PPPP_HHZ_2022_08_24.seed
# CN_PPPP_HHZ_2022_08_25.seed
# CN_PPPP_HHZ_2022_08_26.seed
# CN_PPPP_HHZ_2022_08_27.seed
# CN_PPPP_HHZ_2022_08_28.seed
# CN_PPPP_HHZ_2022_08_29.seed
# CN_PPPP_HHZ_2022_08_30.seed
# CN_PPPP_HHZ_2022_08_31.seed
# CN_PPPP_HHZ_2022_09_01.seed
# CN_PPPP_HHZ_2022_09_02.seed
# CN_PPPP_HHZ_2022_09_03.seed
# CN_PPPP_HHZ_2022_09_04.seed
# CN_PPPP_HHZ_2022_09_05.seed
# CN_PPPP_HHZ_2022_09_06.seed
# CN_PPPP_HHZ_2022_09_07.seed
# CN_PPPP_HHZ_2022_09_08.seed
# CN_PPPP_HHZ_2022_09_09.seed
# CN_PPPP_HHZ_2022_09_10.seed
# CN_PPPP_HHZ_2022_09_11.seed
# CN_PPPP_HHZ_2022_09_12.seed
# CN_PPPP_HHZ_2022_09_13.seed
# CN_PPPP_HHZ_2022_09_14.seed
# CN_PPPP_HHZ_2022_09_15.seed
# CN_PPPP_HHZ_2022_09_16.seed
# CN_PPPP_HHZ_2022_09_17.seed
# CN_PPPP_HHZ_2022_09_18.seed
# CN_PPPP_HHZ_2022_09_19.seed
# CN_PPPP_HHZ_2022_09_20.seed
# CN_PPPP_HHZ_2022_09_21.seed
# CN_PPPP_HHZ_2022_09_22.seed
# CN_PPPP_HHZ_2022_09_23.seed
# CN_PPPP_HHZ_2022_09_24.seed
# CN_PPPP_HHZ_2022_09_25.seed
# CN_PPPP_HHZ_2022_09_26.seed
# CN_PPPP_HHZ_2022_09_27.seed
# CN_PPPP_HHZ_2022_09_28.seed
# CN_PPPP_HHZ_2022_09_29.seed
# CN_PPPP_HHZ_2022_09_30.seed
# CN_PPPP_HHZ_2022_10_01.seed
# CN_PPPP_HHZ_2022_10_02.seed
# CN_PPPP_HHZ_2022_10_03.seed
# CN_PPPP_HHZ_2022_10_04.seed
# CN_PPPP_HHZ_2022_10_05.seed
# CN_PPPP_HHZ_2022_10_06.seed
# CN_PPPP_HHZ_2022_10_07.seed
# CN_PPPP_HHZ_2022_10_08.seed
# CN_PPPP_HHZ_2022_10_09.seed
# CN_PPPP_HHZ_2022_10_10.seed
# CN_PPPP_HHZ_2022_10_11.seed
# CN_PPPP_HHZ_2022_10_12.seed
# CN_PPPP_HHZ_2022_10_13.seed
# CN_PPPP_HHZ_2022_10_14.seed
# CN_PPPP_HHZ_2022_10_15.seed
# CN_PPPP_HHZ_2022_10_16.seed
# CN_PPPP_HHZ_2022_10_17.seed
# CN_PPPP_HHZ_2022_10_18.seed
# CN_PPPP_HHZ_2022_10_19.seed
# CN_PPPP_HHZ_2022_10_20.seed
# CN_PPPP_HHZ_2022_10_21.seed
# CN_PPPP_HHZ_2022_10_22.seed
# CN_PPPP_HHZ_2022_10_23.seed
# CN_PPPP_HHZ_2022_10_24.seed
# CN_PPPP_HHZ_2022_10_25.seed
# CN_PPPP_HHZ_2022_10_26.seed
# CN_PPPP_HHZ_2022_10_27.seed
# CN_PPPP_HHZ_2022_10_28.seed
# CN_PPPP_HHZ_2022_10_29.seed
# CN_PPPP_HHZ_2022_10_30.seed
# CN_PPPP_HHZ_2022_10_31.seed
# CN_PPPP_HHZ_2022_11_01.seed
# CN_PPPP_HHZ_2022_11_02.seed
# CN_PPPP_HHZ_2022_11_03.seed
# CN_PPPP_HHZ_2022_11_04.seed
# CN_PPPP_HHZ_2022_11_05.seed
# CN_PPPP_HHZ_2022_11_06.seed
# CN_PPPP_HHZ_2022_11_07.seed
# CN_PPPP_HHZ_2022_11_08.seed
# CN_PPPP_HHZ_2022_11_09.seed
# CN_PPPP_HHZ_2022_11_10.seed
# CN_PPPP_HHZ_2022_11_11.seed
# CN_PPPP_HHZ_2022_11_12.seed
# CN_PPPP_HHZ_2022_11_13.seed
# CN_PPPP_HHZ_2022_11_14.seed
# CN_PPPP_HHZ_2022_11_15.seed
# CN_PPPP_HHZ_2022_11_16.seed
# CN_PPPP_HHZ_2022_11_17.seed
# CN_PPPP_HHZ_2022_11_18.seed
# CN_PPPP_HHZ_2022_11_19.seed
# CN_PPPP_HHZ_2022_11_20.seed
# CN_PPPP_HHZ_2022_11_21.seed
# CN_PPPP_HHZ_2022_11_22.seed
# CN_PPPP_HHZ_2022_11_23.seed
# CN_PPPP_HHZ_2022_11_24.seed
# CN_PPPP_HHZ_2022_11_25.seed
# CN_PPPP_HHZ_2022_11_26.seed
# CN_PPPP_HHZ_2022_11_27.seed
# CN_PPPP_HHZ_2022_11_28.seed
# CN_PPPP_HHZ_2022_11_29.seed
# CN_PPPP_HHZ_2022_11_30.seed
# c:\Users\javie\OneDrive - INSTITUTO TECNOLOGICO AUTONOMO DE MEXICO\MaestriaEnCienciaDeDatos\EstanciaDeInvestigacion\Popocatepelt\PopocatepetlVolcano\src\features.py:131: RuntimeWarning: divide by zero encountered in log10
#   freq_index = np.log10(ener_high / (ener_low + np.finfo(float).eps))
# c:\Users\javie\miniconda3\envs\estancia_popocatepetl\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2046: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# CN_PPPP_HHZ_2022_12_01.seed
# c:\Users\javie\OneDrive - INSTITUTO TECNOLOGICO AUTONOMO DE MEXICO\MaestriaEnCienciaDeDatos\EstanciaDeInvestigacion\Popocatepelt\PopocatepetlVolcano\src\features.py:131: RuntimeWarning: divide by zero encountered in log10
#   freq_index = np.log10(ener_high / (ener_low + np.finfo(float).eps))
# c:\Users\javie\miniconda3\envs\estancia_popocatepetl\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2046: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# CN_PPPP_HHZ_2022_12_02.seed
# c:\Users\javie\OneDrive - INSTITUTO TECNOLOGICO AUTONOMO DE MEXICO\MaestriaEnCienciaDeDatos\EstanciaDeInvestigacion\Popocatepelt\PopocatepetlVolcano\src\features.py:131: RuntimeWarning: divide by zero encountered in log10
#   freq_index = np.log10(ener_high / (ener_low + np.finfo(float).eps))
# c:\Users\javie\miniconda3\envs\estancia_popocatepetl\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2046: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# CN_PPPP_HHZ_2022_12_03.seed
# CN_PPPP_HHZ_2022_12_04.seed
# CN_PPPP_HHZ_2022_12_05.seed
# CN_PPPP_HHZ_2022_12_06.seed
# CN_PPPP_HHZ_2022_12_07.seed
# CN_PPPP_HHZ_2022_12_08.seed
# CN_PPPP_HHZ_2022_12_09.seed
# CN_PPPP_HHZ_2022_12_10.seed
# CN_PPPP_HHZ_2022_12_11.seed
# CN_PPPP_HHZ_2022_12_12.seed
# CN_PPPP_HHZ_2022_12_13.seed
# CN_PPPP_HHZ_2022_12_14.seed
# CN_PPPP_HHZ_2022_12_15.seed
# CN_PPPP_HHZ_2022_12_16.seed
# CN_PPPP_HHZ_2022_12_17.seed
# CN_PPPP_HHZ_2022_12_18.seed
# CN_PPPP_HHZ_2022_12_19.seed
# CN_PPPP_HHZ_2022_12_20.seed
# CN_PPPP_HHZ_2022_12_21.seed
# CN_PPPP_HHZ_2022_12_22.seed
# CN_PPPP_HHZ_2022_12_23.seed
# CN_PPPP_HHZ_2022_12_24.seed
# CN_PPPP_HHZ_2022_12_25.seed
# CN_PPPP_HHZ_2022_12_26.seed
# CN_PPPP_HHZ_2022_12_27.seed
# CN_PPPP_HHZ_2022_12_28.seed
# CN_PPPP_HHZ_2022_12_29.seed
# CN_PPPP_HHZ_2022_12_30.seed
# CN_PPPP_HHZ_2022_12_31.seed

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(14, 12), sharex=True)
axes[0].scatter(features_df['timestamp'], features_df['energy'], color='paleturquoise', s=10, alpha=0.6, label="Ventana de 10 min")
axes[0].plot(features_df['timestamp'], features_df['energy_movil_media'], color='teal', linewidth=2, label='Media móvil centrada (1 hr)')
axes[0].set_yscale('log')
axes[0].set_title('Energía (Cuadrados medios de la amplitud)')
axes[0].legend(loc='best')

axes[1].scatter(features_df['timestamp'], features_df['kurtosis'], color='lightsteelblue', s=10, alpha=0.5, label = "Ventana de 10 min")
axes[1].plot(features_df['timestamp'], features_df['kurtosis_movil_media'], color='navy', alpha = 1,linewidth=2, label='Media móvil centrada (1 hr)')
axes[1].set_title('Kurtosis')
axes[1].legend(loc='best')

axes[2].scatter(features_df['timestamp'], features_df['frequency_index'], color='#7FB3D5', s=10, alpha=0.5, label = "Ventana de 10 min")
axes[2].plot(features_df['timestamp'], features_df['frequency_index_movil_media'], color='#C0392B', alpha = 1,linewidth=2, label='Media móvil centrada (1 hr)')
axes[2].set_title('Índice de frecuencia')
axes[2].legend(loc='best')

axes[3].scatter(features_df['timestamp'], features_df['entropy'], color='silver', s=10, alpha=0.5, label = "Ventana de 10 min")
axes[3].plot(features_df['timestamp'], features_df['entropy_movil_media'], color='darkorange', alpha = 1,linewidth=2, label='Media móvil centrada (1 hr)')
axes[3].set_title('Entropia')
axes[3].set_xlabel('Fecha')
axes[3].legend(loc='best')

plt.xticks(rotation=45)
plt.tight_layout()
