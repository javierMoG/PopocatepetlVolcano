# %%
import pandas as pd
import obspy 
import os
import re
import logging
import obspy.signal.interpolation as itp
import obspy.core.stream 
import obspy.core.trace
from datetime import datetime
import numpy as np

# %%
os.getcwd()
os.chdir("D:\\Popocatepetl")
os.getcwd()
# Out:
# 'D:\\Popocatepetl'

# %%
st = obspy.read("data/2023/01/01/CN.PPPP._20230101_000000.seed")

# %%
st[0].data.dtype
# Out:
# dtype('int32')

# %%
st = st.select(component="Z")
st.plot()

# %%
# Plot spectrogram for the first trace in the stream
st[0].spectrogram(log=True, dbscale=True, cmap='viridis')

# %%
st = st.resample(sampling_rate = 100)

# %%
# Plot spectrogram for the first trace in the stream
st[0].spectrogram(log=True, dbscale=True, cmap='viridis')
